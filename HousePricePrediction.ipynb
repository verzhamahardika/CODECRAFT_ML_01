# %% [markdown]
# ## Data loading
#
# ### Subtask:
# Load the training and testing datasets.

# %% [markdown]
# **Reasoning**:
# Load the training and testing datasets into pandas DataFrames and display the first 5 rows of each.

# %%
import pandas as pd

# Load the training dataset
df_train = pd.read_csv('datasets/train.csv')

# Load the testing dataset
df_test = pd.read_csv('datasets/test.csv')

# Display the first 5 rows of the training dataset
display(df_train.head())

# Display the first 5 rows of the testing dataset
display(df_test.head())
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Data exploration
#
# ### Subtask:
# Explore the training dataset to understand its structure, identify potential issues, and examine the distributions of key features.

# %% [markdown]
# **Reasoning**:
# Explore the training dataset by examining its basic statistics, missing values, data types, and distributions of key features, as well as calculating and visualizing the correlation matrix of relevant features and the target variable.

# %%
# 1. Data Overview
display(df_train.describe())

# 2. Missing Values
display(df_train.isnull().sum())

# 3. Data Types
display(df_train.info())

# 4. Outlier Detection (Histograms for 'price' and 'GrLivArea')
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.hist(df_train['SalePrice'], bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Sale Price')
plt.ylabel('Frequency')
plt.title('Distribution of Sale Price')

plt.subplot(1, 2, 2)
plt.hist(df_train['GrLivArea'], bins=30, color='lightcoral', edgecolor='black')
plt.xlabel('Above Grade Living Area')
plt.ylabel('Frequency')
plt.title('Distribution of Above Grade Living Area')
plt.tight_layout()
plt.show()


# 5. Correlation Analysis
corr_matrix = df_train[['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea', 'TotalBsmtSF']].corr()
display(corr_matrix)
plt.figure(figsize=(8, 6))
import seaborn as sns
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Key Features and Sale Price')
plt.show()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000  ...
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726  ...
# std       1.112799    30.202904     20.645407   181.066207   456.098091  ...
# ...

# %% [markdown]
# ## Data cleaning
#
# ### Subtask:
# Clean the training and testing datasets.

# %% [markdown]
# **Reasoning**:
# Impute missing values in 'LotFrontage', 'MasVnrArea', 'GarageYrBlt' and 'SalePrice', handle outliers in 'SalePrice' and 'GrLivArea', and apply the same cleaning steps to df_test.

# %%
# Impute missing values
for df in [df_train, df_test]:
    df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].median())
    df['MasVnrArea'] = df['MasVnrArea'].fillna(0)
    df['GarageYrBlt'] = df['GarageYrBlt'].fillna(df['GarageYrBlt'].median())

# Handle outliers in 'SalePrice' and 'GrLivArea' for df_train
df_train = df_train[df_train['GrLivArea'] < 4500]
upper_limit = df_train['SalePrice'].quantile(0.99)
df_train = df_train[df_train['SalePrice'] < upper_limit]

# Verify data cleaning
print("Missing values in df_train:\n", df_train.isnull().sum().sort_values(ascending=False).head(10))
print("\nMissing values in df_test:\n", df_test.isnull().sum().sort_values(ascending=False).head(10))

# Display the cleaned data
display(df_train.head())
display(df_test.head())
# Out:
# Missing values in df_train:
#  PoolQC          1438
# MiscFeature     1389
# Alley           1352
# Fence           1164
# MasVnrType       869
# FireplaceQu      690
# GarageType        81
# GarageQual        81
# GarageCond        81
# GarageFinish      81
# dtype: int64
#
# Missing values in df_test:
#  PoolQC          1456
# MiscFeature     1408
# Alley           1352
# Fence           1169
# MasVnrType       894
# FireplaceQu      730
# GarageFinish      78
# GarageQual        78
# GarageCond        78
# GarageType        76
# dtype: int64
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
# ...

# %% [markdown]
# ## Feature engineering
#
# ### Subtask:
# Prepare the features for the linear regression model.

# %% [markdown]
# **Reasoning**:
# Select the relevant features ('GrLivArea', 'BedroomAbvGr', 'FullBath') from df_train and df_test to create X_train and X_test, and create y_train from 'SalePrice' in df_train.  Handle any missing values by imputation.

# %%
import numpy as np

# Select features for X_train and X_test
features = ['GrLivArea', 'BedroomAbvGr', 'FullBath']
X_train = df_train[features]
X_test = df_test[features]

# Create y_train
y_train = df_train['SalePrice']

# Impute missing values in X_train and X_test using the median
for col in features:
    X_train[col] = X_train[col].fillna(X_train[col].median())
    X_test[col] = X_test[col].fillna(X_test[col].median())

# Convert to NumPy arrays for model training
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
# Out:
# C:\Users\TUF GAMING\AppData\Local\Temp\ipykernel_21372\2371718611.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_train[col] = X_train[col].fillna(X_train[col].median())
# C:\Users\TUF GAMING\AppData\Local\Temp\ipykernel_21372\2371718611.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test[col] = X_test[col].fillna(X_test[col].median())
# C:\Users\TUF GAMING\AppData\Local\Temp\ipykernel_21372\2371718611.py:13: SettingWithCopyWarning:
# ...

# %% [markdown]
# **Reasoning**:
# The previous code had SettingWithCopyWarning, which can be avoided by using .loc to assign values.  I will correct the code and re-run it.

# %%
import numpy as np

# Select features for X_train and X_test
features = ['GrLivArea', 'BedroomAbvGr', 'FullBath']
X_train = df_train[features]
X_test = df_test[features]

# Create y_train
y_train = df_train['SalePrice']

# Impute missing values in X_train and X_test using the median
for col in features:
    X_train.loc[:, col] = X_train[col].fillna(X_train[col].median())
    X_test.loc[:, col] = X_test[col].fillna(X_test[col].median())

# Convert to NumPy arrays for model training
X_train = X_train.values
X_test = X_test.values
y_train = y_train.values

# %% [markdown]
# ## Data splitting
#
# ### Subtask:
# Split the training data into training and validation sets.

# %% [markdown]
# **Reasoning**:
# Split the training data into training and validation sets using train_test_split.

# %%
from sklearn.model_selection import train_test_split

# Split data into training and validation sets
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

# %% [markdown]
# ## Model training
#
# ### Subtask:
# Train a linear regression model.

# %% [markdown]
# **Reasoning**:
# Train the linear regression model using the training data and make predictions on the validation set.

# %%
from sklearn.linear_model import LinearRegression

# Instantiate the linear regression model
model = LinearRegression()

# Train the model
model.fit(X_train_split, y_train_split)

# Make predictions on the validation set
y_pred = model.predict(X_val)

# %% [markdown]
# ## Model evaluation
#
# ### Subtask:
# Evaluate the linear regression model's performance on the validation set.

# %% [markdown]
# **Reasoning**:
# Evaluate the linear regression model's performance using MSE, RMSE, and R-squared.

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np

# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_val, y_pred)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)

# Calculate R-squared (R2) score
r2 = r2_score(y_val, y_pred)

# Print the evaluation metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2) Score: {r2}")
# Out:
# Mean Squared Error (MSE): 1875291710.8839638
# Root Mean Squared Error (RMSE): 43304.63844536707
# R-squared (R2) Score: 0.5845125956026689

# %% [markdown]
# ## Data preparation
#
# ### Subtask:
# Prepare the test data for prediction using the same steps as the training data.

# %% [markdown]
# **Reasoning**:
# Select the features from the test dataset, handle missing values using the same method as the training data, and convert the result to a NumPy array.

# %%
# Select features for X_test
features = ['GrLivArea', 'BedroomAbvGr', 'FullBath']
X_test_final = df_test[features]

# Impute missing values in X_test_final using the median from the training data
for col in features:
    X_test_final.loc[:, col] = X_test_final[col].fillna(df_train[col].median())

# Convert to NumPy array
X_test_final = X_test_final.values

# %% [markdown]
# ## Model training
#
# ### Subtask:
# Retrain the linear regression model using the entire training dataset.

# %% [markdown]
# **Reasoning**:
# Retrain the linear regression model using the entire training dataset and make predictions on the test data.

# %%
from sklearn.linear_model import LinearRegression

# Instantiate a new LinearRegression model
model_final = LinearRegression()

# Train the model using the entire training dataset
model_final.fit(X_train, y_train)

# Make predictions on the prepared test data
y_pred_final = model_final.predict(X_test_final)

# %% [markdown]
# ## Model evaluation
#
# ### Subtask:
# Model Evaluation and Submission File Creation

# %% [markdown]
# **Reasoning**:
# Load the sample submission file and replace the predictions with the new predictions. Then save the updated dataframe to a new csv file.

# %%
import pandas as pd

# Load the sample submission file
submission_df = pd.read_csv('datasets/sample_submission.csv')

# Replace predictions
submission_df['SalePrice'] = y_pred_final

# Save to a new CSV file
submission_df.to_csv('submission.csv', index=False)

# Verify the submission file
print(submission_df.shape)
display(submission_df.head())
# Out:
# (1459, 2)
#      Id      SalePrice
# 0  1461  120965.949461
# 1  1462  141252.934183
# 2  1463  199234.408189
# 3  1464  196491.070297
# 4  1465  188165.038785

# %% [markdown]
# ## Summary:
#
# ### Q&A
# No questions to answer.
#
# ### Data Analysis Key Findings
# * **Data Cleaning:** Missing values in 'LotFrontage', 'MasVnrArea', and 'GarageYrBlt' were imputed. Outliers were removed from 'SalePrice' and 'GrLivArea' in the training dataset.
# * **Feature Engineering:** 'GrLivArea', 'BedroomAbvGr', and 'FullBath' were selected as features. Missing values in these features were imputed using the median.
# * **Model Evaluation (Validation Set):** The linear regression model achieved an R-squared score of 0.58 on the validation set, indicating it explains approximately 58% of the variance in house prices. The RMSE was 43304.64.
# * **Final Model Training:** The model was retrained on the entire training dataset.
# * **Submission File:** A submission file named 'submission.csv' was created containing the final predictions for the test dataset.
#
#
# ### Insights or Next Steps
# * Explore other features and perform more sophisticated feature engineering to improve model accuracy.
# * Consider different regression models (e.g., Random Forest, Gradient Boosting) to see if they perform better than linear regression.
